# %% [markdown]
# # Ask Spurgeon - Train Gemma 4 E4B on 1500 Examples (Kaggle Ready)
#
# **Goal**: Fine-tune unsloth/gemma-4-E4B-it on the prepared 1500 high-fidelity Spurgeon examples using QLoRA + Unsloth.
#
# This notebook is optimized for **Kaggle** (GPU T4, T4 x2 or P100 recommended). Kaggle gives longer sessions, easy 'Add Data' and Secrets.
#
# ### Quick Start
# 1. Runtime â†’ Change runtime type â†’ GPU (T4 recommended)
# 2. Run all cells
# 3. Training should take 3â€“8 hours on T4 (depending on settings)
#
# Dataset: 1500 examples from `spurgeon_train_1500.jsonl`

# %%
# @title 1. Install Dependencies (Run this first)
# !pip install "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git" -q
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git" -q
# !pip install "transformers==5.5.0" -q
# !pip install --no-deps xformers "trl" peft accelerate bitsandbytes -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# @title Hugging Face Authentication (Kaggle)
import os
from pathlib import Path

# 1. Try to load from Google Colab Secrets first
try:
    from google.colab import userdata
    token = userdata.get('HF_TOKEN')
    if token:
        os.environ["HF_TOKEN"] = token
        print("âœ… HF_TOKEN loaded from Google Colab Secrets!")
except Exception:
    pass

# 2. Try to load from local .env if running in a local environment
if not os.environ.get("HF_TOKEN"):
    for env_path in [Path(".env"), Path("../.env"), Path("../../.env"), Path("ask-spurgeon/.env"), Path("/content/ask-spurgeon/.env")]:
        if env_path.exists():
            with open(env_path, "r", encoding="utf-8") as f:
                for line in f:
                    if line.strip().startswith("HF_TOKEN="):
                        token = line.strip().split("=", 1)[1].strip("'\" ")
                        if token:
                            os.environ["HF_TOKEN"] = token
                            print(f"âœ… HF_TOKEN loaded from local file: {env_path}")
                            break

# 3. If still not authenticated, prompt interactive login
if not os.environ.get("HF_TOKEN"):
    print("ðŸ”‘ HF_TOKEN not found in Secrets or .env. Prompting interactive login...")
    try:
        from huggingface_hub import notebook_login
        notebook_login()
    except ImportError:
        print("huggingface_hub not installed. Run pip install huggingface_hub")
else:
    print("ðŸŽ‰ Successfully authenticated with Hugging Face!")

# %%
# @title 2. Clone the repository
# !git clone https://github.com/elViRafa/ask-spurgeon.git
# %cd ask-spurgeon
# Out:
# fatal: destination path 'ask-spurgeon' already exists and is not an empty directory.
# /content/ask-spurgeon

# %%
# @title 3. Set Up Save Path (Google Drive or Kaggle Working Directory)
import os
import sys

# Check if running in Kaggle or Colab
IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ
IS_COLAB = "COLAB_GPU" in os.environ or "google.colab" in sys.modules

if IS_COLAB:
    print("Detected Google Colab environment. Mounting Google Drive...")
    try:
        from google.colab import drive
        drive.mount('/content/drive')
        SAVE_PATH = "/content/drive/MyDrive/Spurgeon_Gemma4_E4B_QLoRA_1500"
    except Exception as e:
        print(f"Error mounting Drive: {e}. Saving locally to /content/outputs")
        SAVE_PATH = "/content/outputs/Spurgeon_Gemma4_E4B_QLoRA_1500"
elif IS_KAGGLE:
    print("Detected Kaggle Notebook environment. Saving to Kaggle working directory...")
    SAVE_PATH = "/kaggle/working/Spurgeon_Gemma4_E4B_QLoRA_1500"
else:
    print("Detected local environment.")
    SAVE_PATH = "./fine_tuning/models/Spurgeon_Gemma4_E4B_QLoRA_1500"

print("Models will be saved to:", SAVE_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Models will be saved to: /content/drive/MyDrive/Spurgeon_8B_QLoRA_1500

# %%
# @title 4. Training Configuration (Good for T4)
MODEL_NAME = "unsloth/gemma-4-E4B-it"
DATASET_PATH = "fine_tuning/data/spurgeon_train_1500.jsonl"
OUTPUT_DIR = SAVE_PATH if 'SAVE_PATH' in globals() else "outputs/spurgeon-gemma-4-12b-1500"

# Conservative settings for free T4 (16GB VRAM)
MAX_SEQ_LENGTH = 2048          # Reduce if you get OOM
BATCH_SIZE = 1
GRAD_ACCUM = 16                # Effective batch = 16
LEARNING_RATE = 1e-4
EPOCHS = 1                     # Start with 1 epoch for testing
LORA_R = 32                    # Lower rank for T4

print("Configuration ready for 1500 examples.")
# Out:
# Configuration ready for 1500 examples.

# %%
# @title 5. Load Model + Apply LoRA (Unsloth)
from unsloth import FastLanguageModel
from unsloth.chat_templates import get_chat_template

print("Loading model...")
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    load_in_4bit = True,
)

model = FastLanguageModel.get_peft_model(
    model,
    r = LORA_R,
    lora_alpha = 64,
    lora_dropout = 0.05,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    use_gradient_checkpointing = "unsloth",
)

try:
    tokenizer = get_chat_template(tokenizer, chat_template="gemma-4")
except Exception as e:
    print(f"Warning: Could not apply 'gemma-4' chat template directly: {e}")
    print("Falling back to tokenizer's native chat template or gemma2 fallback.")
    if getattr(tokenizer, "chat_template", None) is None:
        try:
            tokenizer = get_chat_template(tokenizer, chat_template="gemma2")
        except Exception:
            tokenizer = get_chat_template(tokenizer, chat_template="gemma")

print("Model loaded and LoRA applied!")
# Out:
# ðŸ¦¥ Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ðŸ¦¥ Unsloth Zoo will now patch everything to make training faster!
# Loading model...
# ==((====))==  Unsloth 2026.5.9: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Unsloth: Will load unsloth/llama-3.1-8b-instruct-bnb-4bit as a legacy tokenizer.
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# ...

# %%
# @title 6. Load Dataset
from datasets import load_dataset
from pathlib import Path

dataset_path = Path(DATASET_PATH)

if not dataset_path.exists():
    print("Dataset not found in the repo.")
    print("Please upload 'spurgeon_train_1500.jsonl' using the Colab file browser (left sidebar â†’ Files â†’ Upload).")
    print("Or mount Google Drive and set the correct path.")
    raise FileNotFoundError(f"Dataset not found at {DATASET_PATH}")

print(f"Loading dataset: {DATASET_PATH}")
dataset = load_dataset("json", data_files=DATASET_PATH, split="train")

def formatting_func(examples):
    texts = []
    for messages in examples["messages"]:
        text = tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=False
        )
        texts.append(text)
    return {"text": texts}

dataset = dataset.map(formatting_func, batched=True, remove_columns=dataset.column_names)
print(f"Loaded {len(dataset)} examples")
# Out:
# Loading dataset: fine_tuning/data/spurgeon_train_1500.jsonl
# Loaded 1500 examples

# %%
import torch
import inspect
import transformers
from transformers import Trainer

# Runtime Monkeypatch to fix transformers/trl version incompatibility
original_init = Trainer.__init__
def patched_init(self, *args, **kwargs):
    if "tokenizer" in kwargs:
        if "processing_class" not in kwargs:
            kwargs["processing_class"] = kwargs.pop("tokenizer")
        else:
            kwargs.pop("tokenizer")
    return original_init(self, *args, **kwargs)
Trainer.__init__ = patched_init
transformers.Trainer.__init__ = patched_init

try:
    import unsloth.models._utils as unsloth_utils
    if hasattr(unsloth_utils, "_original_trainer_init"):
        orig_unsloth_init = unsloth_utils._original_trainer_init
        def patched_unsloth_init(self, *args, **kwargs):
            if "tokenizer" in kwargs:
                if "processing_class" not in kwargs:
                    kwargs["processing_class"] = kwargs.pop("tokenizer")
                else:
                    kwargs.pop("tokenizer")
            return orig_unsloth_init(self, *args, **kwargs)
        unsloth_utils._original_trainer_init = patched_unsloth_init
except Exception as e:
    pass

# @title 7. Start Training
from trl import SFTTrainer
try:
    from trl import SFTConfig
except ImportError:
    SFTConfig = None

# Safer settings for T4 GPU (most free Colab users)
fp16 = not torch.cuda.is_bf16_supported()
bf16 = torch.cuda.is_bf16_supported()

if SFTConfig is not None:
    # Modern TRL API
    training_args = SFTConfig(
        output_dir = OUTPUT_DIR,
        per_device_train_batch_size = BATCH_SIZE,
        gradient_accumulation_steps = GRAD_ACCUM,
        warmup_steps = 20,
        num_train_epochs = EPOCHS,
        learning_rate = LEARNING_RATE,
        fp16 = fp16,
        bf16 = bf16,
        logging_steps = 10,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 42,
        save_strategy = "epoch",
        max_seq_length = MAX_SEQ_LENGTH,
        dataset_text_field = "text",
        packing = False,
    )
    
    # Check signature for tokenizer/processing_class compatibility
    sig = inspect.signature(SFTTrainer.__init__)
    trainer_kwargs = {
        "model": model,
        "train_dataset": dataset,
        "args": training_args,
    }
    if "processing_class" in sig.parameters:
        trainer_kwargs["processing_class"] = tokenizer
    else:
        trainer_kwargs["tokenizer"] = tokenizer
        
    trainer = SFTTrainer(**trainer_kwargs)
else:
    # Legacy TRL API
    from transformers import TrainingArguments
    training_args = TrainingArguments(
        output_dir = OUTPUT_DIR,
        per_device_train_batch_size = BATCH_SIZE,
        gradient_accumulation_steps = GRAD_ACCUM,
        warmup_steps = 20,
        num_train_epochs = EPOCHS,
        learning_rate = LEARNING_RATE,
        fp16 = fp16,
        bf16 = bf16,
        logging_steps = 10,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 42,
        save_strategy = "epoch",
    )
    
    trainer = SFTTrainer(
        model = model,
        tokenizer = tokenizer,
        train_dataset = dataset,
        dataset_text_field = "text",
        max_seq_length = MAX_SEQ_LENGTH,
        args = training_args,
        packing = False,
    )

print("Starting training on 1500 examples...")
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10027/1867883057.py in <cell line: 0>()
#      67     )
#      68
# ---> 69     trainer = SFTTrainer(
#      70         model = model,
#      71         tokenizer = tokenizer,
#
# /usr/local/lib/python3.12/dist-packages/trl/trainer/sft_trainer.py in __init__(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     321             )
#     322
# --> 323         super().__init__(
#     324             model=model,
#     325             args=args,
#
# ...

# %%
# @title 8. Save the Model
print("Saving LoRA adapter...")
trainer.save_model(OUTPUT_DIR)
print(f"LoRA saved to: {OUTPUT_DIR}")

# Optional: Merge and save 16-bit version
# model.save_pretrained_merged(f"{OUTPUT_DIR}-merged", tokenizer, save_method="merged_16bit")
# print("Merged model saved!")

# %% [markdown]
# ## 9. Test the Fine-Tuned Model (Inference)
#
# Now that the model is trained, let's verify that it actually speaks in Spurgeon's voice while remaining **faithful** to the retrieved context.
#
# We will load a test context and question, format it using Gemma 4's chat template, and use Unsloth's fast inference with **real-time streaming** to generate the response.

# %%
# @title 9. Real-Time Inference Test
from unsloth import FastLanguageModel
from transformers import TextStreamer

# 1. Set model to fast inference mode
FastLanguageModel.for_inference(model)

# 2. Prepare a test sermon context and a question
test_context = (
    "In my sermon 'Songs in the Night', I declared: 'Any man can sing in the day. "
    "It is easy to sing when we can read the notes by daylight; but the skillful singer "
    "is he who can sing when there is not a ray of light to read by. Songs in the night come "
    "only from God; they are not in the power of man. They are the sovereign gifts of heaven.'"
)
test_question = "Where do songs in the night come from, and is it easy for man to sing them?"

# 3. Format using Gemma 4 chat template (matching the training format)
messages = [
    {
        "role": "system",
        "content": (
            "You are Charles Haddon Spurgeon. You must answer the user's question "
            "using ONLY the information in the CONTEXT section below. Do not add external knowledge.\n\n"
            f"CONTEXT:\n{test_context}"
        )
    },
    {
        "role": "user",
        "content": test_question
    }
]

inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
).to("cuda")

# 4. Setup text streamer for real-time output
text_streamer = TextStreamer(tokenizer, skip_prompt=True)

print("=== Retrieved Context ===")
print(test_context)
print("\n=== User Question ===")
print(test_question)
print("\n=== Generated Answer (Spurgeon's Voice) ===")

# 5. Generate with streaming
_ = model.generate(
    input_ids = inputs,
    streamer = text_streamer,
    max_new_tokens = 256,
    use_cache = True,
    temperature = 0.6,
    top_p = 0.9,
)

# %% [markdown]
# ## After Training
#
# 1. Download the adapter from the output folder (or Drive)
# 2. Upload to Hugging Face (optional)
# 3. Use it in your RAG pipeline as the generator
#
# See `fine_tuning/FINE_TUNING_PLAN.md` for next steps and evaluation ideas.

# %% [markdown]
# ## 10. Merge LoRA Adapter (for TGI Deployment)
#
# After training, you usually only have a **LoRA adapter**. To deploy with TGI (or for easier use), it is highly recommended to **merge** the adapter weights into the base model.
#
# This section helps you do that directly in Colab.

# %%
# @title 10. Merge LoRA Adapter (Fast Unsloth Native Method)
from unsloth import FastLanguageModel
from pathlib import Path
import os
import sys

# Check environment
IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ

# --- CONFIGURATION ---
# Where your trained LoRA adapter is saved
if 'SAVE_PATH' in globals():
    ADAPTER_PATH = SAVE_PATH
else:
    if IS_KAGGLE:
        ADAPTER_PATH = "/kaggle/working/Spurgeon_Gemma4_E4B_QLoRA_1500"
    else:
        ADAPTER_PATH = "/content/drive/MyDrive/Spurgeon_Gemma4_E4B_QLoRA_1500"

# Where to save the merged model
if IS_KAGGLE:
    MERGED_SAVE_PATH = "/kaggle/working/Spurgeon-Gemma4-E4B-Merged-16bit"
else:
    MERGED_SAVE_PATH = "/content/drive/MyDrive/Spurgeon-Gemma4-E4B-Merged-16bit"

# 1. Check if model is already loaded in the active session
if 'model' in globals() and 'tokenizer' in globals():
    print("✅ Found trained model and tokenizer in the active session. Using them for merging.")
else:
    print(f"🔄 Model not found in session. Loading trained adapter from: {ADAPTER_PATH}")
    if not Path(ADAPTER_PATH).exists():
        print(f"❌ Error: Adapter path {ADAPTER_PATH} does not exist.")
        print("Please ensure your path is correct!")
    else:
        # Load the base model and automatically attach the saved LoRA adapter
        model, tokenizer = FastLanguageModel.from_pretrained(
            model_name = ADAPTER_PATH,
            max_seq_length = 2048, # Must match your training max_seq_length
            load_in_4bit = True,   # Low RAM loading
        )
        print("✅ Model and adapter loaded successfully from disk!")

# 2. Perform the optimized merge
if 'model' in globals():
    print(f"Merging adapter and saving 16-bit model to: {MERGED_SAVE_PATH}")
    print("This will download the base model optimized weights and merge them natively.")
    print("It is highly optimized and prevents System RAM from crashing!")
    
    model.save_pretrained_merged(
        MERGED_SAVE_PATH,
        tokenizer,
        save_method="merged_16bit",
    )
    
    print("\n✅ Merge completed successfully via Unsloth!")
    print(f"Merged model saved at: {MERGED_SAVE_PATH}")
else:
    print("❌ Error: No model available to merge.")

# %% [markdown]
# ## 11. Upload Merged Model to Hugging Face
#
# Depending on where you merged your model, choose the appropriate option to upload it:
#
# ### Option A: Local PC Upload (Recommended if you merged locally on your PC CPU/GPU)
# If you ran the merge locally on your computer, the model files are stored on your local hard drive. **Google Colab's cloud server cannot access your local C:\ drive directly.**
#
# To upload the model, simply open a terminal **locally on your Windows PC** in the `search-sermons` directory and run:
# ```powershell
# .venv\Scripts\python.exe fine_tuning\scripts\upload_to_hf.py
# ```
# *(This standalone utility will read your Hugging Face write token from `.env` or prompt you interactively, and upload the local folder immediately!)*
#
# ### Option B: Cloud Colab Upload (If you merged using the Colab T4/A100 GPU)
# If you successfully ran the merge inside the Google Colab cloud runtime (Step 10 above), the merged model is stored on your Google Drive.
#
# 1. Mount your Google Drive.
# 2. Ensure `MERGED_SAVE_PATH` in the cell below is set to your Google Drive path:
# ```python
# MERGED_SAVE_PATH = "/content/drive/MyDrive/Spurgeon-Gemma4-E4B-Merged-16bit"
# ```
# 3. Run the code cell below to perform the upload from the cloud container!

# %%
# @title 11. (Optional) Upload Merged Model to Hugging Face
from huggingface_hub import login, HfApi
import os

# Use MERGED_SAVE_PATH from step 10 if available and exists, otherwise default to Drive path
if 'MERGED_SAVE_PATH' in globals() and os.path.exists(globals()['MERGED_SAVE_PATH']):
    upload_path = globals()['MERGED_SAVE_PATH']
else:
    if "KAGGLE_KERNEL_RUN_TYPE" in os.environ:
        upload_path = "/kaggle/working/Spurgeon-Gemma4-E4B-Merged-16bit"
    else:
        upload_path = "/content/drive/MyDrive/Spurgeon-Gemma4-E4B-Merged-16bit"

HF_REPO_ID = "rafaelvieirar1r/gemma-4-12b-spurgeon-generator"   # <-- CHANGE THIS

print("Logging into Hugging Face...")
login()   # You will be prompted for your HF write token

print(f"Uploading merged model from: {upload_path} to repo: {HF_REPO_ID}")
api = HfApi()
api.upload_folder(
    folder_path=upload_path,
    repo_id=HF_REPO_ID,
    repo_type="model",
    commit_message="Upload merged Spurgeon fine-tuned model (1500 examples)"
)

print("\n✅ Upload complete!")
print(f"Your model is now available at: https://huggingface.co/{HF_REPO_ID}")
# Out:
# Logging into Hugging Face...
# Uploading merged model to: rafaelvieirar1r/llama-3.1-8b-spurgeon-generator
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2075/575849799.py in <cell line: 0>()
#      11 print(f"Uploading merged model to: {HF_REPO_ID}")
#      12 api = HfApi()
# ---> 13 api.upload_folder(
#      14     folder_path=MERGED_SAVE_PATH,
#      15     repo_id=HF_REPO_ID,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#      86         kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#      87
# ---> 88         return fn(*args, **kwargs)
#      89
#      90     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in _inner(self, *args, **kwargs)
#    2054
# ...

# %% [markdown]
# ## Next Steps After Merging
#
# 1. Download the merged model from your Drive (or the path you chose).
# 2. Upload it to the Hugging Face Hub (the cell above can do this).
# 3. Use the TGI deployment guide in `fine_tuning/spaces/tgi-deployment/DEPLOY_TGI.md` to create a free inference Space.
# 4. Call your fine-tuned Spurgeon generator from your main RAG app using the OpenAI-compatible endpoint.

# %% [markdown]
# ## 12. Convert Merged Model to GGUF (for CPU / llama.cpp Deployment)
#
# If you want to deploy your fine-tuned model on **free CPU** (via Hugging Face Spaces or locally with Ollama/llama.cpp), you need to convert the merged model to **GGUF** format.
#
# This is the recommended format for efficient CPU inference.
#
# **Note**: This step is heavy and benefits greatly from a GPU runtime in Colab.

# %%
# @title 12.1 Clone llama.cpp (needed for GGUF conversion)
# !git clone https://github.com/ggerganov/llama.cpp --depth 1
# %cd llama.cpp
# !make -j
# %cd ..

# %%
# @title 12.2 Convert Merged Model to GGUF (f16 first)
from pathlib import Path
import os

# Uses the MERGED_SAVE_PATH from the previous merge cell
MERGED_MODEL_PATH = MERGED_SAVE_PATH

if "KAGGLE_KERNEL_RUN_TYPE" in os.environ:
    GGUF_OUTPUT_DIR = "/kaggle/working/Spurgeon_GGUF"
else:
    GGUF_OUTPUT_DIR = "/content/drive/MyDrive/Spurgeon_GGUF"

Path(GGUF_OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

OUTPUT_GGUF = f"{GGUF_OUTPUT_DIR}/Spurgeon-Gemma4-E4B-f16.gguf"

print(f"Converting merged model to GGUF (f16)...")
# !python llama.cpp/convert_hf_to_gguf.py \
    {MERGED_MODEL_PATH} \
    --outfile {OUTPUT_GGUF} \
    --outtype f16

print(f"\n✅ f16 GGUF created at: {OUTPUT_GGUF}")

# %%
# @title 12.3 (Recommended) Quantize to Q4_K_M for CPU
# This produces a much smaller and faster model (~4.5-5 GB)

QUANTIZED_OUTPUT = f"{GGUF_OUTPUT_DIR}/Spurgeon-Gemma4-E4B-Q4_K_M.gguf"

print("Quantizing to Q4_K_M...")
# !llama.cpp/quantize {OUTPUT_GGUF} {QUANTIZED_OUTPUT} q4_k_m

print(f"\nâœ… Quantized GGUF ready at: {QUANTIZED_OUTPUT}")
print("Upload this file for efficient CPU deployment.")

# %% [markdown]
# ## After GGUF Conversion
#
# 1. Upload the quantized GGUF file (`Spurgeon-Gemma4-E4B-Q4_K_M.gguf`) to a Hugging Face repo.
# 2. Use the ready CPU deployment files in `fine_tuning/spaces/cpu-llama-cpp/` to create a free inference Space.
# 3. Update your main RAG app to use the new endpoint (`LLM_PROVIDER=openai`).

# %% [markdown]
# ## 13. Save / Upload Model directly to Kaggle
#
# You can save the trained model (both the raw LoRA adapter and the merged model) directly to Kaggle Models or Datasets.
#
# To upload to Kaggle, you will need your Kaggle API credentials (username and key). Go to Kaggle -> Settings -> API -> 'Create New Token' to get your `kaggle.json`.
#
# You can securely store these credentials in your Kaggle Notebook Secrets (KAGGLE_USERNAME and KAGGLE_KEY).

# %%
# @title 13.1 Load Kaggle Credentials & Authenticate
import os
import json
from pathlib import Path

kaggle_authenticated = False

# 1. Try to load from Kaggle Secrets (if running in Kaggle Notebook)
try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    username = user_secrets.get_secret("KAGGLE_USERNAME")
    key = user_secrets.get_secret("KAGGLE_KEY")
    if username and key:
        os.environ["KAGGLE_USERNAME"] = username
        os.environ["KAGGLE_KEY"] = key
        print("✅ Kaggle credentials loaded successfully from Kaggle Secrets!")
        kaggle_authenticated = True
except Exception:
    pass

# 2. Try to load from local/Drive .env file
if not kaggle_authenticated:
    for env_path in [Path(".env"), Path("../.env"), Path("../../.env"), Path("ask-spurgeon/.env"), Path("/content/ask-spurgeon/.env")]:
        if env_path.exists():
            with open(env_path, "r", encoding="utf-8") as f:
                for line in f:
                    if line.strip().startswith("KAGGLE_"):
                        parts = line.strip().split("=", 1)
                        if len(parts) == 2:
                            os.environ[parts[0].strip()] = parts[1].strip("'\" ")
            if os.environ.get("KAGGLE_USERNAME") and os.environ.get("KAGGLE_KEY"):
                print(f"✅ Kaggle credentials loaded from local file: {env_path}")
                kaggle_authenticated = True
                break

# 3. Create kaggle.json configuration file if credentials exist
if os.environ.get("KAGGLE_USERNAME") and os.environ.get("KAGGLE_KEY"):
    kaggle_dir = Path.home() / ".kaggle"
    kaggle_dir.mkdir(parents=True, exist_ok=True)
    kaggle_json_path = kaggle_dir / "kaggle.json"
    with open(kaggle_json_path, "w") as f:
        json.dump({
            "username": os.environ["KAGGLE_USERNAME"],
            "key": os.environ["KAGGLE_KEY"]
        }, f)
    # Set permissions
    try:
        os.chmod(kaggle_json_path, 0o600)
    except Exception:
        pass
    print("✅ Kaggle API client successfully authenticated!")
else:
    print("⚠️ Kaggle credentials NOT found in Secrets or .env file.")
    print("Please add KAGGLE_USERNAME and KAGGLE_KEY to your Kaggle Notebook Secrets (Add-ons -> Secrets)")
    print("or set them manually in the cell below.")

# %%
# @title 13.2 Option A: Upload to Kaggle Model Registry (Using kagglehub)
# This will upload the model files to an existing model page on Kaggle.
# Note: You must first create the model container on the Kaggle website (kaggle.com/models -> "New Model").
# Example handle: 'username/model-slug/framework/variation-slug'
# e.g., 'rafaelvieirar1r/gemma4-spurgeon/pytorch/lora-adapter'

import kagglehub
import os

# CONFIGURATION
# 1. The Kaggle model handle to upload to
KAGGLE_MODEL_HANDLE = "your_username/your_model_slug/pytorch/variation_slug" # <-- CHANGE THIS

# 2. Path to folder you want to upload (raw LoRA adapter or Merged Model)
# Defaulting to LoRA Adapter path
UPLOAD_DIR = SAVE_PATH if 'SAVE_PATH' in globals() else "/kaggle/working/Spurgeon_Gemma4_E4B_QLoRA_1500"

if not os.environ.get("KAGGLE_USERNAME") or not os.environ.get("KAGGLE_KEY"):
    print("❌ Error: You are not authenticated. Please run the cell above and verify your credentials.")
elif not os.path.exists(UPLOAD_DIR):
    print(f"❌ Error: The directory to upload does not exist: {UPLOAD_DIR}")
elif "your_username" in KAGGLE_MODEL_HANDLE:
    print("⚠️ Please edit KAGGLE_MODEL_HANDLE with your actual Kaggle username and model slug.")
else:
    print(f"Uploading files from '{UPLOAD_DIR}' to Kaggle Model: '{KAGGLE_MODEL_HANDLE}'...")
    try:
        kagglehub.model_upload(
            handle=KAGGLE_MODEL_HANDLE,
            local_model_dir=UPLOAD_DIR,
            version_notes="Upload fine-tuned Spurgeon model"
        )
        print("🎉 Upload to Kaggle Model Registry complete!")
    except Exception as e:
        print(f"❌ Upload failed: {e}")
        print("Make sure you created the model page first on Kaggle (kaggle.com/models -> New Model)")

# %%
# @title 13.3 Option B: Upload as a Kaggle Dataset (programmatically creates it if new!)
# This is fully scriptable and creates the dataset for you automatically.

import json
import subprocess
import os
from pathlib import Path

# CONFIGURATION
# 1. Your Kaggle username and the slug for the dataset
DATASET_SLUG = "spurgeon-gemma4-e4b-model" # URL-safe name (hyphens, no spaces)

# 2. Path to folder you want to upload (raw LoRA adapter or Merged Model)
UPLOAD_DIR = SAVE_PATH if 'SAVE_PATH' in globals() else "/kaggle/working/Spurgeon_Gemma4_E4B_QLoRA_1500"

# 3. Choose whether to upload the raw LoRA adapter, the merged model, or GGUF files
# (Choose by uncommenting/editing UPLOAD_DIR as needed)
# UPLOAD_DIR = MERGED_SAVE_PATH if 'MERGED_SAVE_PATH' in globals() else "/kaggle/working/Spurgeon-Gemma4-E4B-Merged-16bit"

if not os.environ.get("KAGGLE_USERNAME") or not os.environ.get("KAGGLE_KEY"):
    print("❌ Error: You are not authenticated. Please run the credentials cell first.")
elif not os.path.exists(UPLOAD_DIR):
    print(f"❌ Error: The directory to upload does not exist: {UPLOAD_DIR}")
else:
    username = os.environ["KAGGLE_USERNAME"]
    dataset_id = f"{username}/{DATASET_SLUG}"
    
    # 1. Create dataset-metadata.json in the folder
    metadata = {
        "title": "Spurgeon Gemma 4 E4B Fine-Tuned Model",
        "id": dataset_id,
        "licenses": [{"name": "Apache-2.0"}]
    }
    
    metadata_path = Path(UPLOAD_DIR) / "dataset-metadata.json"
    with open(metadata_path, "w") as f:
        json.dump(metadata, f, indent=4)
        
    print(f"Generated metadata at: {metadata_path}")
    
    # 2. Check if dataset already exists on Kaggle
    print(f"Checking status of dataset: {dataset_id}...")
    status_cmd = f"kaggle datasets status {dataset_id}"
    status_proc = subprocess.run(status_cmd.split(), capture_output=True, text=True)
    
    if "NotFound" in status_proc.stderr or "NotFound" in status_proc.stdout or status_proc.returncode != 0:
        # Create new dataset
        print(f"Dataset '{dataset_id}' not found. Creating a NEW private dataset on Kaggle...")
        create_cmd = f"kaggle datasets create -p {UPLOAD_DIR} -u"
        create_proc = subprocess.run(create_cmd.split(), capture_output=True, text=True)
        print(create_proc.stdout)
        if create_proc.returncode == 0:
            print(f"🎉 New Kaggle dataset created successfully: https://www.kaggle.com/datasets/{dataset_id}")
        else:
            print(f"❌ Failed to create dataset: {create_proc.stderr}")
    else:
        # Update existing dataset with new version
        print(f"Dataset '{dataset_id}' exists. Uploading a NEW VERSION of the dataset...")
        update_cmd = f"kaggle datasets version -p {UPLOAD_DIR} -m 'Update fine-tuned model weights'"
        update_proc = subprocess.run(update_cmd.split(), capture_output=True, text=True)
        print(update_proc.stdout)
        if update_proc.returncode == 0:
            print(f"🎉 Kaggle dataset updated successfully: https://www.kaggle.com/datasets/{dataset_id}")
        else:
            print(f"❌ Failed to update dataset: {update_proc.stderr}")
